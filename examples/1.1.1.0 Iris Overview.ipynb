# %% [markdown]
# # Iris
#
# At the Met Office we maintain a python library called Iris for working with gridded model data.
#
# Iris implements a data model based on the [CF conventions](http://cfconventions.org/) giving you a powerful, format-agnostic interface for working with your data. It excels when working with multi-dimensional Earth Science data, where tabular representations become unwieldy and inefficient.
#
# Here is an example of loading and plotting some data.

# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

import iris
import iris.plot as iplt
import iris.quickplot as qplt

# %%
temperature = iris.load_cube("/data/met-office/open-license/metoffice_ukv_daily/t1o5m_max/ukv_daily_t1o5m_max_20200114.nc", 'air_temperature')
temperature
# Out:
# <iris 'Cube' of air_temperature / (K) (grid_latitude: 808; grid_longitude: 621)>

# %%
# Plot #1: contourf with axes longitude from -180 to 180
plt.figure(figsize=(24, 24))
plt.subplot(121)
qplt.contourf(temperature, 15)
plt.gca().coastlines('50m')
# Out:
# /envs/work/lab-full-fat/lib/python3.8/site-packages/cartopy/io/__init__.py:260: DownloadWarning: Downloading: https://naciscdn.org/naturalearth/50m/physical/ne_50m_coastline.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)

# %%
# Plot #2
plt.figure(figsize=(24, 24))
proj = ccrs.PlateCarree(central_longitude=-90.0)
plt.subplot(122, projection=proj)
qplt.contourf(temperature, 15)
plt.gca().coastlines('50m')
iplt.show()
